# %%
import pandas as pd
import numpy as np
import os

base = '/workspaces/hospital-financial-risk-analysis/data'

print("Files found:")
print(os.listdir(base))
# Out:
# Files found:
# ['Hospital_Provider_Cost_Report_2021.csv', 'Hospital_Provider_Cost_Report_2020.csv', 'Hospital_Provider_Cost_Report_2023_updated.csv', 'Hospital_Provider_Cost_Report_2019.csv', 'Hospital_Provider_Cost_Report_2022.csv']

# %%
import pandas as pd
import numpy as np
import os

base = '/workspaces/hospital-financial-risk-analysis/data'

files = {
    2019: f'{base}/Hospital_Provider_Cost_Report_2019.csv',
    2020: f'{base}/Hospital_Provider_Cost_Report_2020.csv',
    2021: f'{base}/Hospital_Provider_Cost_Report_2021.csv',
    2022: f'{base}/Hospital_Provider_Cost_Report_2022.csv',
    2023: f'{base}/Hospital_Provider_Cost_Report_2023_updated.csv',
}

dfs = []
for year, file in files.items():
    df = pd.read_csv(file)
    df['year'] = year
    dfs.append(df)
    print(f"Loaded {year}: {df.shape[0]} rows")

df = pd.concat(dfs, ignore_index=True)
print(f"\nCombined: {df.shape}")
# Out:
# /tmp/ipykernel_9358/2954288003.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['year'] = year
# Loaded 2019: 6121 rows
# Loaded 2020: 6059 rows
# Loaded 2021: 6053 rows
# Loaded 2022: 6064 rows
# Loaded 2023: 6103 rows
#
# Combined: (30400, 118)

# %%
# See all columns clearly
for i, col in enumerate(df.columns.tolist()):
    print(f"{i}: {col}")
# Out:
# 0: rpt_rec_num
# 1: Provider CCN
# 2: Hospital Name
# 3: Street Address
# 4: City
# 5: State Code
# 6: Zip Code
# 7: County
# 8: Medicare CBSA Number
# 9: Rural Versus Urban
# 10: CCN Facility Type
# 11: Provider Type
# 12: Type of Control
# 13: Fiscal Year Begin Date
# 14: Fiscal Year End Date
# 15: FTE - Employees on Payroll
# 16: Number of Interns and Residents (FTE)
# 17: Total Days Title V
# 18: Total Days Title XVIII
# 19: Total Days Title XIX
# 20: Total Days (V + XVIII + XIX + Unknown)
# 21: Number of Beds
# 22: Total Bed Days Available
# 23: Total Discharges Title V
# 24: Total Discharges Title XVIII
# 25: Total Discharges Title XIX
# 26: Total Discharges (V + XVIII + XIX + Unknown)
# 27: Number of Beds + Total for all Subproviders
# 28: Hospital Total Days Title V For Adults & Peds
# 29: Hospital Total Days Title XVIII For Adults & Peds
# 30: Hospital Total Days Title XIX For Adults & Peds
# 31: Hospital Total Days (V + XVIII + XIX + Unknown) For Adults & Peds
# 32: Hospital Number of Beds For Adults & Peds
# 33: Hospital Total Bed Days Available For Adults & Peds
# 34: Hospital Total Discharges Title V For Adults & Peds
# 35: Hospital Total Discharges Title XVIII For Adults & Peds
# 36: Hospital Total Discharges Title XIX For Adults & Peds
# 37: Hospital Total Discharges (V + XVIII + XIX + Unknown) For Adults & Peds
# 38: Cost of Charity Care
# 39: Total Bad Debt Expense
# 40: Cost of Uncompensated Care
# 41: Total Unreimbursed and Uncompensated Care
# 42: Total Salaries From Worksheet A
# 43: Overhead Non-Salary Costs
# 44: Depreciation Cost
# 45: Total Costs
# 46: Inpatient Total Charges
# 47: Outpatient Total Charges
# 48: Combined Outpatient + Inpatient Total Charges
# 49: Wage-Related Costs (Core)
# 50: Wage-Related Costs (RHC/FQHC)
# 51: Total Salaries (adjusted)
# 52: Contract Labor: Direct Patient Care
# 53: Wage Related Costs for Part - A Teaching Physicians
# 54: Wage Related Costs for Interns and Residents
# 55: Cash on Hand and in Banks
# 56: Temporary Investments
# 57: Notes Receivable
# 58: Accounts Receivable
# 59: Less: Allowances for Uncollectible Notes and Accounts Receivable
# 60: Inventory
# 61: Prepaid Expenses
# 62: Other Current Assets
# 63: Total Current Assets
# 64: Land
# 65: Land Improvements
# 66: Buildings
# 67: Leasehold Improvements
# 68: Fixed Equipment
# 69: Major Movable Equipment
# 70: Minor Equipment Depreciable
# 71: Health Information Technology Designated Assets
# 72: Total Fixed Assets
# 73: Investments
# 74: Other Assets
# 75: Total Other Assets
# 76: Total Assets
# 77: Accounts Payable
# 78: Salaries, Wages, and Fees Payable
# 79: Payroll Taxes Payable
# 80: Notes and Loans Payable (Short Term)
# 81: Deferred Income
# 82: Other Current Liabilities
# 83: Total Current Liabilities
# 84: Mortgage Payable
# 85: Notes Payable
# 86: Unsecured Loans
# 87: Other Long Term Liabilities
# 88: Total Long Term Liabilities
# 89: Total Liabilities
# 90: General Fund Balance
# 91: Total Fund Balances
# 92: Total Liabilities and Fund Balances
# 93: DRG Amounts Other Than Outlier Payments
# 94: DRG Amounts Before October 1
# 95: DRG Amounts After October 1
# 96: Outlier Payments For Discharges
# 97: Disproportionate Share Adjustment
# 98: Allowable DSH Percentage
# 99: Managed Care Simulated Payments
# 100: Total IME Payment
# 101: Inpatient Revenue
# 102: Outpatient Revenue
# 103: Total Patient Revenue
# 104: Less Contractual Allowance and Discounts on Patients' Accounts
# 105: Net Patient Revenue
# 106: Less Total Operating Expense
# 107: Net Income from Service to Patients
# 108: Total Other Income
# 109: Total Income
# 110: Total Other Expenses
# 111: Net Income
# 112: Cost To Charge Ratio
# 113: Net Revenue from Medicaid
# 114: Medicaid Charges
# 115: Net Revenue from Stand-Alone CHIP
# 116: Stand-Alone CHIP Charges
# 117: year

# %%
print(df.columns[24:114].tolist())
# Out:
# ['Total Discharges Title XVIII', 'Total Discharges Title XIX', 'Total Discharges (V + XVIII + XIX + Unknown)', 'Number of Beds + Total for all Subproviders', 'Hospital Total Days Title V For Adults & Peds', 'Hospital Total Days Title XVIII For Adults & Peds', 'Hospital Total Days Title XIX For Adults & Peds', 'Hospital Total Days (V + XVIII + XIX + Unknown) For Adults & Peds', 'Hospital Number of Beds For Adults & Peds', 'Hospital Total Bed Days Available For Adults & Peds', 'Hospital Total Discharges Title V For Adults & Peds', 'Hospital Total Discharges Title XVIII For Adults & Peds', 'Hospital Total Discharges Title XIX For Adults & Peds', 'Hospital Total Discharges (V + XVIII + XIX + Unknown) For Adults & Peds', 'Cost of Charity Care', 'Total Bad Debt Expense', 'Cost of Uncompensated Care', 'Total Unreimbursed and Uncompensated Care', 'Total Salaries From Worksheet A', 'Overhead Non-Salary Costs', 'Depreciation Cost', 'Total Costs', 'Inpatient Total Charges', 'Outpatient Total Charges', 'Combined Outpatient + Inpatient Total Charges', 'Wage-Related Costs (Core)', 'Wage-Related Costs (RHC/FQHC)', 'Total Salaries (adjusted)', 'Contract Labor: Direct Patient Care', 'Wage Related Costs for Part - A Teaching Physicians', 'Wage Related Costs for Interns and Residents', 'Cash on Hand and in Banks', 'Temporary Investments', 'Notes Receivable', 'Accounts Receivable', 'Less: Allowances for Uncollectible Notes and Accounts Receivable', 'Inventory', 'Prepaid Expenses', 'Other Current Assets', 'Total Current Assets', 'Land', 'Land Improvements', 'Buildings', 'Leasehold Improvements', 'Fixed Equipment', 'Major Movable Equipment', 'Minor Equipment Depreciable', 'Health Information Technology Designated Assets', 'Total Fixed Assets', 'Investments', 'Other Assets', 'Total Other Assets', 'Total Assets', 'Accounts Payable', 'Salaries, Wages, and Fees Payable', 'Payroll Taxes Payable', 'Notes and Loans Payable (Short Term)', 'Deferred Income', 'Other Current Liabilities', 'Total Current Liabilities', 'Mortgage Payable', 'Notes Payable', 'Unsecured Loans', 'Other Long Term Liabilities', 'Total Long Term Liabilities', 'Total Liabilities', 'General Fund Balance', 'Total Fund Balances', 'Total Liabilities and Fund Balances', 'DRG Amounts Other Than Outlier Payments', 'DRG Amounts Before October 1', 'DRG Amounts After October 1', 'Outlier Payments For Discharges', 'Disproportionate Share Adjustment', 'Allowable DSH Percentage', 'Managed Care Simulated Payments', 'Total IME Payment', 'Inpatient Revenue', 'Outpatient Revenue', 'Total Patient Revenue', "Less Contractual Allowance and Discounts on Patients' Accounts", 'Net Patient Revenue', 'Less Total Operating Expense', 'Net Income from Service to Patients', 'Total Other Income', 'Total Income', 'Total Other Expenses', 'Net Income', 'Cost To Charge Ratio', 'Net Revenue from Medicaid']

# %%
# Select only the columns we care about
cols_to_keep = [
    'Provider CCN', 'Hospital Name', 'City', 'State Code', 
    'Rural Versus Urban', 'Type of Control', 'Provider Type',
    'Number of Beds', 'FTE - Employees on Payroll',
    'Total Days Title XVIII', 'Total Days Title XIX',
    'Total Discharges (V + XVIII + XIX + Unknown)',
    'Cost of Charity Care', 'Total Bad Debt Expense',
    'Cost of Uncompensated Care', 'Total Unreimbursed and Uncompensated Care',
    'Total Costs', 'Total Patient Revenue', 'Net Patient Revenue',
    'Net Income', 'Net Revenue from Medicaid', 'Medicaid Charges',
    'Total Assets', 'Total Liabilities', 'Net Income from Service to Patients',
    'Disproportionate Share Adjustment', 'year'
]

df_clean = df[cols_to_keep].copy()
print(df_clean.shape)
print(df_clean.head())
# Out:
# (6064, 27)
#    Provider CCN                         Hospital Name         City State Code  \
# 0        344028  STRATEGIC BEHAVIORAL CENTER - GARNER       GARNER         NC
# 1        180078  PAUL B. HALL REGIONAL MEDICAL CENTER  PAINTSVILLE         KY
# 2        520210  MARSHFIELD MEDICAL CENTER-EAU CLAIRE   EAU CLAIRE         WI
# 3         63037         COBALT REHAB HOSP WESTMINSTER  WESTMINSTER         CO
# 4        340123           AMERICAN HEALTHCARE SYSTEMS     ASHEBORO         NC
#
#   Rural Versus Urban  Type of Control  Provider Type  Number of Beds  \
# 0                NaN                1              4             NaN
# 1                  R                4              1            72.0
# 2                  U                2              1            44.0
# 3                  U                4              5            40.0
# 4                  U                2              1           145.0
#
#    FTE - Employees on Payroll  Total Days Title XVIII  ...  \
# 0                         NaN                     NaN  ...
# 1                       30.38                   335.0  ...
# 2                      792.25                  1245.0  ...
# 3                       22.80                   134.0  ...
# 4                      173.01                   792.0  ...
#
#    Total Patient Revenue  Net Patient Revenue  Net Income  \
# 0                    NaN                  NaN         NaN
# 1             67671556.0            6182531.0   2785847.0
# 2            155498762.0           61135683.0  -3565548.0
# 3              1716578.0             671606.0  -1980346.0
# 4            181045877.0           24492145.0 -11909764.0
#
#    Net Revenue from Medicaid  Medicaid Charges  Total Assets  \
# 0                        NaN               NaN           NaN
# 1                  1114125.0        26708472.0 -3.598010e+05
# 2                 14333809.0        18797586.0  2.101426e+09
# 3                        NaN               NaN  5.896079e+06
# 4                  1724073.0         6249901.0 -2.803442e+07
#
#    Total Liabilities  Net Income from Service to Patients  \
# 0                NaN                                  NaN
# 1       6.632660e+05                             634470.0
# 2       1.452186e+09                           -4259661.0
# 3       6.254531e+06                           -1980346.0
# 4      -1.661320e+07                           -5248749.0
#
#    Disproportionate Share Adjustment  year
# 0                                NaN  2022
# 1                            16804.0  2022
# 2                            48580.0  2022
# 3                                NaN  2022
# 4                            59194.0  2022
#
# [5 rows x 27 columns]

# %%
# Check missing values
print("Missing values per column:")
print(df_clean.isnull().sum())
print(f"\nTotal missing: {df_clean.isnull().sum().sum()}")

# Check data types
print("\nData types:")
print(df_clean.dtypes)

# Basic statistics
print("\nBasic statistics:")
print(df_clean.describe())
# Out:
# Missing values per column:
# Provider CCN                                       0
# Hospital Name                                      0
# City                                               0
# State Code                                         0
# Rural Versus Urban                                83
# Type of Control                                    0
# Provider Type                                      0
# Number of Beds                                    94
# FTE - Employees on Payroll                       118
# Total Days Title XVIII                           151
# Total Days Title XIX                            1013
# Total Discharges (V + XVIII + XIX + Unknown)     102
# Cost of Charity Care                            1820
# Total Bad Debt Expense                          1608
# Cost of Uncompensated Care                      1549
# Total Unreimbursed and Uncompensated Care       1528
# Total Costs                                       83
# Total Patient Revenue                            243
# Net Patient Revenue                              241
# Net Income                                        90
# Net Revenue from Medicaid                       1679
# Medicaid Charges                                1691
# Total Assets                                     302
# Total Liabilities                                332
# Net Income from Service to Patients               85
# Disproportionate Share Adjustment               3335
# year                                               0
# dtype: int64
#
# Total missing: 16147
#
# Data types:
# Provider CCN                                      int64
# Hospital Name                                       str
# City                                                str
# State Code                                          str
# Rural Versus Urban                                  str
# Type of Control                                   int64
# Provider Type                                     int64
# Number of Beds                                  float64
# FTE - Employees on Payroll                      float64
# Total Days Title XVIII                          float64
# Total Days Title XIX                            float64
# Total Discharges (V + XVIII + XIX + Unknown)    float64
# Cost of Charity Care                            float64
# Total Bad Debt Expense                          float64
# Cost of Uncompensated Care                      float64
# Total Unreimbursed and Uncompensated Care       float64
# Total Costs                                     float64
# Total Patient Revenue                           float64
# Net Patient Revenue                             float64
# Net Income                                      float64
# Net Revenue from Medicaid                       float64
# Medicaid Charges                                float64
# Total Assets                                    float64
# Total Liabilities                               float64
# Net Income from Service to Patients             float64
# Disproportionate Share Adjustment               float64
# year                                              int64
# dtype: object
#
# Basic statistics:
#         Provider CCN  Type of Control  Provider Type  Number of Beds  \
# count    6064.000000      6064.000000    6064.000000     5970.000000
# mean   269404.638522         4.178595       1.708773      133.943384
# std    160322.536510         3.200321       1.431237      181.238049
# min     10001.000000         1.000000       1.000000        1.000000
# 25%    140157.250000         2.000000       1.000000       25.000000
# 50%    260021.000000         2.000000       1.000000       64.000000
# 75%    393035.250000         5.000000       1.000000      170.000000
# max    713029.000000        13.000000      10.000000     2850.000000
#
#        FTE - Employees on Payroll  Total Days Title XVIII  \
# count                 5946.000000             5913.000000
# mean                  1174.646171             7604.045831
# std                  13569.179424            12124.613554
# min                      0.050000                1.000000
# 25%                    129.112500              989.000000
# 50%                    288.250000             2819.000000
# 75%                    902.735000             9297.000000
# max                 987647.000000           176816.000000
#
#        Total Days Title XIX  Total Discharges (V + XVIII + XIX + Unknown)  \
# count           5051.000000                                   5962.000000
# mean            3390.437735                                   5393.199094
# std             8052.593393                                   8945.703408
# min                1.000000                                      1.000000
# 25%              121.000000                                    392.000000
# 50%              680.000000                                   1518.000000
# 75%             3083.000000                                   6809.500000
# max           175703.000000                                 140787.000000
#
#        Cost of Charity Care  Total Bad Debt Expense  ...  \
# count          4.244000e+03            4.456000e+03  ...
# mean           6.755720e+06            1.133608e+07  ...
# std            2.019244e+07            2.310611e+07  ...
# min            1.000000e+00           -4.426020e+05  ...
# 25%            3.468900e+05            1.276664e+06  ...
# 50%            1.657734e+06            4.177600e+06  ...
# 75%            5.919576e+06            1.241764e+07  ...
# max            6.442514e+08            5.472091e+08  ...
#
#        Total Patient Revenue  Net Patient Revenue    Net Income  \
# count           5.821000e+03         5.823000e+03  5.974000e+03
# mean            8.949145e+08         2.222892e+08  7.117901e+06
# std             1.913337e+09         4.702025e+08  1.289053e+08
# min             1.000000e+00        -3.634873e+08 -1.224029e+09
# 25%             5.260346e+07         2.271741e+07 -3.868518e+06
# 50%             1.897480e+08         6.070950e+07  7.509730e+05
# 75%             9.610737e+08         2.270296e+08  7.395911e+06
# max             4.144500e+10         8.944229e+09  7.919570e+09
#
#        Net Revenue from Medicaid  Medicaid Charges  Total Assets  \
# count               4.385000e+03      4.373000e+03  5.762000e+03
# mean                3.172794e+07      1.942532e+08  3.599847e+08
# std                 8.750084e+07      4.248297e+08  1.598392e+09
# min                -1.449717e+07      1.000000e+01 -1.341894e+09
# 25%                 2.851322e+06      1.118957e+07  2.148161e+07
# 50%                 9.163034e+06      5.166032e+07  6.220950e+07
# 75%                 2.784502e+07      1.940467e+08  2.251700e+08
# max                 3.173354e+09      7.968634e+09  5.465559e+10
#
#        Total Liabilities  Net Income from Service to Patients  \
# count       5.732000e+03                         5.979000e+03
# mean        1.517100e+08                        -1.213235e+07
# std         1.213490e+09                         1.469759e+08
# min        -4.225592e+09                        -1.625376e+09
# 25%         5.170914e+06                        -1.248723e+07
# 50%         2.179394e+07                        -2.037805e+06
# 75%         8.249834e+07                         2.852722e+06
# max         5.336559e+10                         7.864650e+09
#
#        Disproportionate Share Adjustment    year
# count                       2.729000e+03  6064.0
# mean                        1.165691e+06  2022.0
# std                         1.857584e+06     0.0
# min                         1.000000e+00  2022.0
# 25%                         1.337730e+05  2022.0
# 50%                         5.015380e+05  2022.0
# 75%                         1.440343e+06  2022.0
# max                         2.848275e+07  2022.0
#
# [8 rows x 23 columns]

# %%
# Drop rows where our target variable is missing
df_clean = df_clean.dropna(subset=['Cost of Uncompensated Care'])
print(f"Rows after dropping missing target: {df_clean.shape[0]}")

# Check remaining missing values
print("\nRemaining missing values:")
print(df_clean.isnull().sum())
# Out:
# Rows after dropping missing target: 4515
#
# Remaining missing values:
# Provider CCN                                       0
# Hospital Name                                      0
# City                                               0
# State Code                                         0
# Rural Versus Urban                                 0
# Type of Control                                    0
# Provider Type                                      0
# Number of Beds                                     6
# FTE - Employees on Payroll                        13
# Total Days Title XVIII                            30
# Total Days Title XIX                             426
# Total Discharges (V + XVIII + XIX + Unknown)      12
# Cost of Charity Care                             271
# Total Bad Debt Expense                            60
# Cost of Uncompensated Care                         0
# Total Unreimbursed and Uncompensated Care          0
# Total Costs                                        0
# Total Patient Revenue                             23
# Net Patient Revenue                               21
# Net Income                                         0
# Net Revenue from Medicaid                        153
# Medicaid Charges                                 164
# Total Assets                                      68
# Total Liabilities                                 73
# Net Income from Service to Patients                2
# Disproportionate Share Adjustment               1823
# year                                               0
# dtype: int64

# %%
# Fill numerical columns with median (safer than mean for financial data)
numerical_cols = [
    'Number of Beds', 'FTE - Employees on Payroll',
    'Total Days Title XVIII', 'Total Days Title XIX',
    'Total Discharges (V + XVIII + XIX + Unknown)',
    'Cost of Charity Care', 'Total Bad Debt Expense',
    'Total Patient Revenue', 'Net Patient Revenue',
    'Net Income', 'Net Revenue from Medicaid', 'Medicaid Charges',
    'Total Assets', 'Total Liabilities', 'Net Income from Service to Patients',
    'Disproportionate Share Adjustment'
]

for col in numerical_cols:
    median_val = df_clean[col].median()
    df_clean[col] = df_clean[col].fillna(median_val)

# Total Days Title XIX has 2110 missing - fill with 0 
# (some hospitals may genuinely have no Medicaid patients)
df_clean['Total Days Title XIX'] = df_clean['Total Days Title XIX'].fillna(0)

# Verify no missing values remain
print("Missing values after cleaning:")
print(df_clean.isnull().sum())
print(f"\nFinal dataset shape: {df_clean.shape}")
# Out:
# Missing values after cleaning:
# Provider CCN                                    0
# Hospital Name                                   0
# City                                            0
# State Code                                      0
# Rural Versus Urban                              0
# Type of Control                                 0
# Provider Type                                   0
# Number of Beds                                  0
# FTE - Employees on Payroll                      0
# Total Days Title XVIII                          0
# Total Days Title XIX                            0
# Total Discharges (V + XVIII + XIX + Unknown)    0
# Cost of Charity Care                            0
# Total Bad Debt Expense                          0
# Cost of Uncompensated Care                      0
# Total Unreimbursed and Uncompensated Care       0
# Total Costs                                     0
# Total Patient Revenue                           0
# Net Patient Revenue                             0
# Net Income                                      0
# Net Revenue from Medicaid                       0
# Medicaid Charges                                0
# Total Assets                                    0
# Total Liabilities                               0
# Net Income from Service to Patients             0
# Disproportionate Share Adjustment               0
# year                                            0
# dtype: int64
#
# Final dataset shape: (4515, 27)

# %%
# Save cleaned dataset
df_clean.to_csv('../data/cleaned_hospital_data.csv', index=False)
print("Cleaned dataset saved successfully!")
print(f"Final shape: {df_clean.shape}")
# Out:
# Cleaned dataset saved successfully!
# Final shape: (4515, 27)
